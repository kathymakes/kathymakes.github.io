# %% [markdown]
# ## peppers poem

# %%
import tracery

# %%
from tracery.modifiers import base_english
import random

# %%
pepper1 = random.choice(peppers)
letter1 = pepper1[0].lower()

# pepper1 = [x for x in peppers if x[0].lower() == letter1]
firstname1 = [x for x in firstname if x[0].lower() == letter1]
lastname1 = [x for x in lastname if x[0].lower() == letter1]
verb1 = [x for x in verb if x[0] == letter1]
unit1 = [x for x in unit if x[0] == letter1]
adj1 = [x for x in adj if x[0] == letter1]

print(pepper1)
print("")
print(firstname1)
print(lastname1)
print(verb1)
print(unit1)
print(adj1)
# Out:
# Aleppo
#
# ['Alessio', 'Alena', 'Anna', 'Andrew', 'Andre', 'Anthony']
# ['Allen', 'Albers', 'Anders']
# ['alley-oop', 'alter', 'annotate', 'annihilate', 'anchor']
# ['alley', 'alliance', 'answer', 'anthill', 'aggregate']
# ['alien', 'alliterating', 'annoying', 'annexed', 'anchovied', 'antsy']

# %%
rules = {
    "sentence1":"#firstname# #lastname# #verb.ed# #unit.a# of #adj# #peppers.lowercase.s#.",
#     "sentence2":"#unit.a.capitalize# of #adj# #peppers.lowercase# #firstname# #lastname# did #verb#.",
    "sentence3":"If #firstname# #lastname# #verb.ed# #unit.a# of #adj# #peppers.lowercase.s#,",
    "sentence4":"How many #unit.s# of #peppers.lowercase# should #firstname# #lastname# #verb#?",
    "firstname": firstname1,
    "lastname": lastname1,
    "verb":verb1,
    "unit":unit1,
    "adj":adj1,      
    "peppers": pepper1,
}

grammar = tracery.Grammar(rules)
grammar.add_modifiers(base_english)

print("")

print(pepper1 + " 🌶")
print("")
    
for i in range(1):
    print(grammar.flatten("#sentence1#"))
    print(grammar.flatten("#sentence1#"))
    print(grammar.flatten("#sentence1#"))
    print("")

    print(grammar.flatten("#sentence3#"))
    print(grammar.flatten("#sentence4#"))
    print("")

# %%
firstname = [
        "Alessio",
        "Alena",
        "Anna",
        "Andrew",
        "Andre",
        "Anthony",
        "Bane",
        "Bonnie",
        "Belle",
        "Bessie",
        "Casanova",
        "Cayla",
        "Charlotte",
        "Chester",
        "Connie",
        "Dane",
        "Dominic",
        "Dory",
        "Destiny",
        "Fresca",
        "Freddie",
        "Fressia",
        "Frida",
        "Fran",
        "Frodo",
        "Halla",
        "Habibi",
        "Harry",
        "Hannah",
        "Melissa",
        "Mohammad",
        "Millie",
        "Pedro",
        "Patsy",
        "Peter",
        "Penny",
        "Pablo",
        "Sherry",
        "Sandy",
        "Sirius",
        "Stevey",
        "Shoko",
        "Shira",
        "Tobias",
        "Tony",
        "Tanyel"
]

# %%
lastname = [
        "Allen",
        "Albers",
        "Anders",
        "Banister",
        "Biel",
        "Borris",
        "Benjamin",
        "Bone",
        "Bass",
        "Casava",
        "Cayley",
        "Chin",
        "Choi",
        "Curl",
        "Dunder",
        "Duffins",
        "Fran",
        "Fanny",
        "Fir",
        "Fredericks",
        "Helena",
        "Harold",
        "Halls",
        "Madison",
        "Meng",
        "Malik",
        "Pedro",
        "Peso",
        "Piper",
        "Pimms",
        "Peebles",
        "Serra",
        "Shitoshi",
        "Sorrel",
        "Shine",
        "T.",
        "Ticks",
        "Toby",
        "Thomas"
]

# %%
verb = [
        
        "alley-oop",
        "alter",
        "annotate",
        "annihilate",
        "anchor",
        "banish",
        "belt",
        "boot",
        "braise",
        "brag",
        "bill",
        "case",
        "can",
        "cherish",
        "chop",
        "chip",
        "crush",
        "culture",
        "coy",
        "dust",
        "dangle",
        "disguise",
        "dab",
        "divine",
        "damage",
        "frequent",
        "federate",
        "free",
        "frack",
        "holler",
        "heap",
        "half",
        "hack",
        "heal",
        "muddle",
        "massacre",
        "mat",
        "miss",
        "peddle",
        "pacify",
        "pick",
        "pummel",
        "probe",
        "pleat",
        "prick",
        "peeled",
        "sear",
        "shift",
        "shield",
        "sniff",
        "ship",
        "tape",
        "tap",
        "test",
        "tickled",
        "traffick"
    ]

# %%
unit = [
        "alley",
        "alliance",
        "answer",
        "anthill",
        "aggregate",
        "bag",
        "bushel",
        "basket",
        "bulletin",
        "billion",
        "bond",
        "casket",
        "canyon",
        "chest",
        "chew",
        "chunk",
        "centimeter",
        "crate",
        "dungeon",
        "desk",
        "doorway",
        "dunce",
        "franchise",
        "folder",
        "feast",
        "hoard",
        "heap",
        "hack",
        "history",
        "horticultures",
        "hundred",
        "mound",
        "message",
        "mass",
        "million",
        "puddle",
        "passage",
        "peck",
        "pint",
        "pound",
        "plate",
        "placard",
        "strain",
        "sheet",
        "stretch",
        "shaft",
        "shingle",
        "tabloid",
        "tapas",
        "topiary"
        "tub",
    
    ]

# %%
adj = [
    
    "alien",
    "alliterating",
    "annoying",
    "annexed",
    "anchovied",
    "antsy",
    "banished",
    "bored",
    "baneful",
    "bellowing",
    "beastly",
    "bullied",
    "cascading",
    "chaotic",
    "chilly",
    "chunky",
    "chopped",
    "curvaceous",
    "dandy",
    "dirty",
    "dormant",
    "dapper",
    "distinguished",
    "dinky",
    "fresh",
    "fragrant",
    "funny",
    "flacid",
    "freaky",
    "false",
    "festering",
    "hilarious",
    "holesome",
    "homey",
    "hoarse",
    "haploid",
    "holy",
    "helpless",
    "horned",
    "halved",
    "medicinal",
    "magical",
    "minty",
    "meandering",
    "padded",
    "passive",
    "pickled",
    "pinned",
    "piddled",
    "proper",
    "proprietary",
    "pumpkin-spice",
    "precious",
    "playful",
    "serrated",
    "shitty",
    "sorted",
    "shimmering",
    "shiney",
    "sloppy",
    "tapered",
    "toothy",
    "tinny",
    "tabby"
]

# %%
peppers = [
    
        "Aleppo",
		"Anaheim",
		"Ancho",
		"Banana pepper",
		"Bell pepper",
		"Cascabel",
		"Cayenne",
		"Chilaca",
		"Chungyang",
		"Cubanelle",
		"Dundicut",
		"Fresno",
        "Habanero",
		"Medusa",
		"Padrón",
		"Pasilla",
		"Peter",
		"Pimento",
		"Poblano",
		"Serrano",
		"Shishito",
    	"Tabasco",

    ]
