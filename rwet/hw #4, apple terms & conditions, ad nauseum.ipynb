# %% [markdown]
# # import necessary things! testing out:

# %%
import random
from collections import Counter

# %%
def ngrams_for_sequence(n, seq):
    return [tuple(seq[i:i+n]) for i in range(len(seq)-n+1)]

# %%
apple_terms = ngrams_for_sequence(5, open("terms_conditions.txt").read().split())
apple_terms
# Out:
# [('These', 'terms', 'and', 'conditions', 'create'),
#  ('terms', 'and', 'conditions', 'create', 'a'),
#  ('and', 'conditions', 'create', 'a', 'contract'),
#  ('conditions', 'create', 'a', 'contract', 'between'),
#  ('create', 'a', 'contract', 'between', 'you'),
#  ('a', 'contract', 'between', 'you', 'and'),
#  ('contract', 'between', 'you', 'and', 'Apple'),
#  ('between', 'you', 'and', 'Apple', '(the'),
#  ('you', 'and', 'Apple', '(the', '“Agreement”).'),
#  ('and', 'Apple', '(the', '“Agreement”).', 'Please'),
#  ('Apple', '(the', '“Agreement”).', 'Please', 'read'),
#  ('(the', '“Agreement”).', 'Please', 'read', 'the'),
#  ('“Agreement”).', 'Please', 'read', 'the', 'Agreement'),
#  ('Please', 'read', 'the', 'Agreement', 'carefully.'),
#  ('read', 'the', 'Agreement', 'carefully.', 'To'),
#  ('the', 'Agreement', 'carefully.', 'To', 'confirm'),
#  ('Agreement', 'carefully.', 'To', 'confirm', 'your'),
#  ('carefully.', 'To', 'confirm', 'your', 'understanding'),
#  ('To', 'confirm', 'your', 'understanding', 'and'),
#  ('confirm', 'your', 'understanding', 'and', 'acceptance'),
#  ('your', 'understanding', 'and', 'acceptance', 'of'),
#  ('understanding', 'and', 'acceptance', 'of', 'the'),
#  ('and', 'acceptance', 'of', 'the', 'Agreement,'),
#  ('acceptance', 'of', 'the', 'Agreement,', 'click'),
#  ('of', 'the', 'Agreement,', 'click', '“Agree.”'),
#  ('the', 'Agreement,', 'click', '“Agree.”', 'A.'),
#  ('Agreement,', 'click', '“Agree.”', 'A.', 'INTRODUCTION'),
#  ('click', '“Agree.”', 'A.', 'INTRODUCTION', 'TO'),
#  ('“Agree.”', 'A.', 'INTRODUCTION', 'TO', 'OUR'),
#  ('A.', 'INTRODUCTION', 'TO', 'OUR', 'SERVICES'),
#  ('INTRODUCTION', 'TO', 'OUR', 'SERVICES', 'This'),
#  ('TO', 'OUR', 'SERVICES', 'This', 'Agreement'),
#  ('OUR', 'SERVICES', 'This', 'Agreement', 'governs'),
#  ('SERVICES', 'This', 'Agreement', 'governs', 'your'),
#  ('This', 'Agreement', 'governs', 'your', 'use'),
#  ('Agreement', 'governs', 'your', 'use', 'of'),
#  ('governs', 'your', 'use', 'of', 'Apple’s'),
#  ('your', 'use', 'of', 'Apple’s', 'services'),
#  ('use', 'of', 'Apple’s', 'services', '(“Services”),'),
#  ('of', 'Apple’s', 'services', '(“Services”),', 'through'),
#  ('Apple’s', 'services', '(“Services”),', 'through', 'which'),
#  ('services', '(“Services”),', 'through', 'which', 'you'),
#  ('(“Services”),', 'through', 'which', 'you', 'can'),
#  ('through', 'which', 'you', 'can', 'buy,'),
#  ('which', 'you', 'can', 'buy,', 'get,'),
#  ('you', 'can', 'buy,', 'get,', 'license,'),
#  ('can', 'buy,', 'get,', 'license,', 'rent'),
#  ('buy,', 'get,', 'license,', 'rent', 'or'),
#  ('get,', 'license,', 'rent', 'or', 'subscribe'),
#  ('license,', 'rent', 'or', 'subscribe', 'to'),
#  ('rent', 'or', 'subscribe', 'to', 'media,'),
#  ('or', 'subscribe', 'to', 'media,', 'apps'),
#  ('subscribe', 'to', 'media,', 'apps', '(“Apps”),'),
#  ('to', 'media,', 'apps', '(“Apps”),', 'and'),
#  ('media,', 'apps', '(“Apps”),', 'and', 'other'),
#  ('apps', '(“Apps”),', 'and', 'other', 'in-app'),
#  ('(“Apps”),', 'and', 'other', 'in-app', 'services'),
#  ('and', 'other', 'in-app', 'services', '(“Content”).'),
#  ('other', 'in-app', 'services', '(“Content”).', 'Our'),
#  ('in-app', 'services', '(“Content”).', 'Our', 'Services'),
#  ('services', '(“Content”).', 'Our', 'Services', 'are:'),
#  ('(“Content”).', 'Our', 'Services', 'are:', 'iTunes'),
#  ('Our', 'Services', 'are:', 'iTunes', 'Store,'),
#  ('Services', 'are:', 'iTunes', 'Store,', 'App'),
#  ('are:', 'iTunes', 'Store,', 'App', 'Store,'),
#  ('iTunes', 'Store,', 'App', 'Store,', 'iBooks'),
#  ('Store,', 'App', 'Store,', 'iBooks', 'Store,'),
#  ('App', 'Store,', 'iBooks', 'Store,', 'Apple'),
#  ('Store,', 'iBooks', 'Store,', 'Apple', 'Music,'),
#  ('iBooks', 'Store,', 'Apple', 'Music,', 'and'),
#  ('Store,', 'Apple', 'Music,', 'and', 'Apple'),
#  ('Apple', 'Music,', 'and', 'Apple', 'News.'),
#  ('Music,', 'and', 'Apple', 'News.', 'Our'),
#  ('and', 'Apple', 'News.', 'Our', 'Services'),
#  ('Apple', 'News.', 'Our', 'Services', 'are'),
#  ('News.', 'Our', 'Services', 'are', 'available'),
#  ('Our', 'Services', 'are', 'available', 'for'),
#  ('Services', 'are', 'available', 'for', 'your'),
#  ('are', 'available', 'for', 'your', 'use'),
#  ('available', 'for', 'your', 'use', 'in'),
#  ('for', 'your', 'use', 'in', 'your'),
#  ('your', 'use', 'in', 'your', 'country'),
#  ('use', 'in', 'your', 'country', 'of'),
#  ('in', 'your', 'country', 'of', 'residence'),
#  ('your', 'country', 'of', 'residence', '(“Home'),
#  ('country', 'of', 'residence', '(“Home', 'Country”).'),
#  ('of', 'residence', '(“Home', 'Country”).', 'To'),
#  ('residence', '(“Home', 'Country”).', 'To', 'use'),
#  ('(“Home', 'Country”).', 'To', 'use', 'our'),
#  ('Country”).', 'To', 'use', 'our', 'Services,'),
#  ('To', 'use', 'our', 'Services,', 'you'),
#  ('use', 'our', 'Services,', 'you', 'need'),
#  ('our', 'Services,', 'you', 'need', 'compatible'),
#  ('Services,', 'you', 'need', 'compatible', 'hardware,'),
#  ('you', 'need', 'compatible', 'hardware,', 'software'),
#  ('need', 'compatible', 'hardware,', 'software', '(latest'),
#  ('compatible', 'hardware,', 'software', '(latest', 'version'),
#  ('hardware,', 'software', '(latest', 'version', 'recommended'),
#  ('software', '(latest', 'version', 'recommended', 'and'),
#  ('(latest', 'version', 'recommended', 'and', 'sometimes'),
#  ('version', 'recommended', 'and', 'sometimes', 'required)'),
#  ('recommended', 'and', 'sometimes', 'required)', 'and'),
#  ('and', 'sometimes', 'required)', 'and', 'Internet'),
#  ('sometimes', 'required)', 'and', 'Internet', 'access'),
#  ('required)', 'and', 'Internet', 'access', '(fees'),
#  ('and', 'Internet', 'access', '(fees', 'may'),
#  ('Internet', 'access', '(fees', 'may', 'apply).'),
#  ('access', '(fees', 'may', 'apply).', 'Our'),
#  ('(fees', 'may', 'apply).', 'Our', 'Services’'),
#  ('may', 'apply).', 'Our', 'Services’', 'performance'),
#  ('apply).', 'Our', 'Services’', 'performance', 'may'),
#  ('Our', 'Services’', 'performance', 'may', 'be'),
#  ('Services’', 'performance', 'may', 'be', 'affected'),
#  ('performance', 'may', 'be', 'affected', 'by'),
#  ('may', 'be', 'affected', 'by', 'these'),
#  ('be', 'affected', 'by', 'these', 'factors.'),
#  ('affected', 'by', 'these', 'factors.', 'B.'),
#  ('by', 'these', 'factors.', 'B.', 'USING'),
#  ('these', 'factors.', 'B.', 'USING', 'OUR'),
#  ('factors.', 'B.', 'USING', 'OUR', 'SERVICES'),
#  ('B.', 'USING', 'OUR', 'SERVICES', 'PAYMENTS,'),
#  ('USING', 'OUR', 'SERVICES', 'PAYMENTS,', 'TAXES,'),
#  ('OUR', 'SERVICES', 'PAYMENTS,', 'TAXES,', 'AND'),
#  ('SERVICES', 'PAYMENTS,', 'TAXES,', 'AND', 'REFUNDS'),
#  ('PAYMENTS,', 'TAXES,', 'AND', 'REFUNDS', 'You'),
#  ('TAXES,', 'AND', 'REFUNDS', 'You', 'can'),
#  ('AND', 'REFUNDS', 'You', 'can', 'acquire'),
#  ('REFUNDS', 'You', 'can', 'acquire', 'Content'),
#  ('You', 'can', 'acquire', 'Content', 'on'),
#  ('can', 'acquire', 'Content', 'on', 'our'),
#  ('acquire', 'Content', 'on', 'our', 'Services'),
#  ('Content', 'on', 'our', 'Services', 'for'),
#  ('on', 'our', 'Services', 'for', 'free'),
#  ('our', 'Services', 'for', 'free', 'or'),
#  ('Services', 'for', 'free', 'or', 'for'),
#  ('for', 'free', 'or', 'for', 'a'),
#  ('free', 'or', 'for', 'a', 'charge,'),
#  ('or', 'for', 'a', 'charge,', 'either'),
#  ('for', 'a', 'charge,', 'either', 'of'),
#  ('a', 'charge,', 'either', 'of', 'which'),
#  ('charge,', 'either', 'of', 'which', 'is'),
#  ('either', 'of', 'which', 'is', 'referred'),
#  ('of', 'which', 'is', 'referred', 'to'),
#  ('which', 'is', 'referred', 'to', 'as'),
#  ('is', 'referred', 'to', 'as', 'a'),
#  ('referred', 'to', 'as', 'a', '“Transaction.”'),
#  ('to', 'as', 'a', '“Transaction.”', 'Each'),
#  ('as', 'a', '“Transaction.”', 'Each', 'Transaction'),
#  ('a', '“Transaction.”', 'Each', 'Transaction', 'is'),
#  ('“Transaction.”', 'Each', 'Transaction', 'is', 'an'),
#  ('Each', 'Transaction', 'is', 'an', 'electronic'),
#  ('Transaction', 'is', 'an', 'electronic', 'contract'),
#  ('is', 'an', 'electronic', 'contract', 'between'),
#  ('an', 'electronic', 'contract', 'between', 'you'),
#  ('electronic', 'contract', 'between', 'you', 'and'),
#  ('contract', 'between', 'you', 'and', 'Apple,'),
#  ('between', 'you', 'and', 'Apple,', 'and/or'),
#  ('you', 'and', 'Apple,', 'and/or', 'you'),
#  ('and', 'Apple,', 'and/or', 'you', 'and'),
#  ('Apple,', 'and/or', 'you', 'and', 'the'),
#  ('and/or', 'you', 'and', 'the', 'entity'),
#  ('you', 'and', 'the', 'entity', 'providing'),
#  ('and', 'the', 'entity', 'providing', 'the'),
#  ('the', 'entity', 'providing', 'the', 'Content'),
#  ('entity', 'providing', 'the', 'Content', 'on'),
#  ('providing', 'the', 'Content', 'on', 'our'),
#  ('the', 'Content', 'on', 'our', 'Services.'),
#  ('Content', 'on', 'our', 'Services.', 'However,'),
#  ('on', 'our', 'Services.', 'However,', 'if'),
#  ('our', 'Services.', 'However,', 'if', 'you'),
#  ('Services.', 'However,', 'if', 'you', 'are'),
#  ('However,', 'if', 'you', 'are', 'a'),
#  ('if', 'you', 'are', 'a', 'customer'),
#  ('you', 'are', 'a', 'customer', 'of'),
#  ('are', 'a', 'customer', 'of', 'Apple'),
#  ('a', 'customer', 'of', 'Apple', 'Distribution'),
#  ('customer', 'of', 'Apple', 'Distribution', 'International'),
#  ('of', 'Apple', 'Distribution', 'International', 'and'),
#  ('Apple', 'Distribution', 'International', 'and', 'you'),
#  ('Distribution', 'International', 'and', 'you', 'acquire'),
#  ('International', 'and', 'you', 'acquire', 'an'),
#  ('and', 'you', 'acquire', 'an', 'App'),
#  ('you', 'acquire', 'an', 'App', 'or'),
#  ('acquire', 'an', 'App', 'or', 'a'),
#  ('an', 'App', 'or', 'a', 'book,'),
#  ('App', 'or', 'a', 'book,', 'Apple'),
#  ('or', 'a', 'book,', 'Apple', 'Distribution'),
#  ('a', 'book,', 'Apple', 'Distribution', 'International'),
#  ('book,', 'Apple', 'Distribution', 'International', 'is'),
#  ('Apple', 'Distribution', 'International', 'is', 'the'),
#  ('Distribution', 'International', 'is', 'the', 'merchant'),
#  ('International', 'is', 'the', 'merchant', 'of'),
#  ('is', 'the', 'merchant', 'of', 'record;'),
#  ('the', 'merchant', 'of', 'record;', 'this'),
#  ('merchant', 'of', 'record;', 'this', 'means'),
#  ('of', 'record;', 'this', 'means', 'that'),
#  ('record;', 'this', 'means', 'that', 'you'),
#  ('this', 'means', 'that', 'you', 'acquire'),
#  ('means', 'that', 'you', 'acquire', 'the'),
#  ('that', 'you', 'acquire', 'the', 'Content'),
#  ('you', 'acquire', 'the', 'Content', 'from'),
#  ('acquire', 'the', 'Content', 'from', 'Apple'),
#  ('the', 'Content', 'from', 'Apple', 'Distribution'),
#  ('Content', 'from', 'Apple', 'Distribution', 'International,'),
#  ('from', 'Apple', 'Distribution', 'International,', 'and'),
#  ('Apple', 'Distribution', 'International,', 'and', 'it'),
#  ('Distribution', 'International,', 'and', 'it', 'is'),
#  ('International,', 'and', 'it', 'is', 'licensed'),
#  ('and', 'it', 'is', 'licensed', 'by'),
#  ('it', 'is', 'licensed', 'by', 'the'),
#  ('is', 'licensed', 'by', 'the', 'App'),
#  ('licensed', 'by', 'the', 'App', 'Provider'),
#  ('by', 'the', 'App', 'Provider', '(as'),
#  ('the', 'App', 'Provider', '(as', 'defined'),
#  ('App', 'Provider', '(as', 'defined', 'below)'),
#  ('Provider', '(as', 'defined', 'below)', 'or'),
#  ('(as', 'defined', 'below)', 'or', 'book'),
#  ('defined', 'below)', 'or', 'book', 'publisher.'),
#  ('below)', 'or', 'book', 'publisher.', 'When'),
#  ('or', 'book', 'publisher.', 'When', 'you'),
#  ('book', 'publisher.', 'When', 'you', 'make'),
#  ('publisher.', 'When', 'you', 'make', 'your'),
#  ('When', 'you', 'make', 'your', 'first'),
#  ('you', 'make', 'your', 'first', 'Transaction,'),
#  ('make', 'your', 'first', 'Transaction,', 'we'),
#  ('your', 'first', 'Transaction,', 'we', 'will'),
#  ('first', 'Transaction,', 'we', 'will', 'ask'),
#  ('Transaction,', 'we', 'will', 'ask', 'you'),
#  ('we', 'will', 'ask', 'you', 'to'),
#  ('will', 'ask', 'you', 'to', 'choose'),
#  ('ask', 'you', 'to', 'choose', 'how'),
#  ('you', 'to', 'choose', 'how', 'frequently'),
#  ('to', 'choose', 'how', 'frequently', 'we'),
#  ('choose', 'how', 'frequently', 'we', 'should'),
#  ('how', 'frequently', 'we', 'should', 'ask'),
#  ('frequently', 'we', 'should', 'ask', 'for'),
#  ('we', 'should', 'ask', 'for', 'your'),
#  ('should', 'ask', 'for', 'your', 'password'),
#  ('ask', 'for', 'your', 'password', 'for'),
#  ('for', 'your', 'password', 'for', 'future'),
#  ('your', 'password', 'for', 'future', 'Transactions.'),
#  ('password', 'for', 'future', 'Transactions.', 'If'),
#  ('for', 'future', 'Transactions.', 'If', 'you'),
#  ('future', 'Transactions.', 'If', 'you', 'enable'),
#  ('Transactions.', 'If', 'you', 'enable', 'Touch'),
#  ('If', 'you', 'enable', 'Touch', 'ID'),
#  ('you', 'enable', 'Touch', 'ID', 'for'),
#  ('enable', 'Touch', 'ID', 'for', 'Transactions,'),
#  ('Touch', 'ID', 'for', 'Transactions,', 'we'),
#  ('ID', 'for', 'Transactions,', 'we', 'will'),
#  ('for', 'Transactions,', 'we', 'will', 'ask'),
#  ('Transactions,', 'we', 'will', 'ask', 'you'),
#  ('we', 'will', 'ask', 'you', 'to'),
#  ('will', 'ask', 'you', 'to', 'authenticate'),
#  ('ask', 'you', 'to', 'authenticate', 'all'),
#  ('you', 'to', 'authenticate', 'all', 'Transactions'),
#  ('to', 'authenticate', 'all', 'Transactions', 'with'),
#  ('authenticate', 'all', 'Transactions', 'with', 'your'),
#  ('all', 'Transactions', 'with', 'your', 'fingerprint.'),
#  ('Transactions', 'with', 'your', 'fingerprint.', 'Manage'),
#  ('with', 'your', 'fingerprint.', 'Manage', 'your'),
#  ('your', 'fingerprint.', 'Manage', 'your', 'password'),
#  ('fingerprint.', 'Manage', 'your', 'password', 'settings'),
#  ('Manage', 'your', 'password', 'settings', 'at'),
#  ('your', 'password', 'settings', 'at', 'any'),
#  ('password', 'settings', 'at', 'any', 'time'),
#  ('settings', 'at', 'any', 'time', 'by'),
#  ('at', 'any', 'time', 'by', 'following'),
#  ('any', 'time', 'by', 'following', 'these'),
#  ('time', 'by', 'following', 'these', 'instructions:'),
#  ('by',
#   'following',
#   'these',
#   'instructions:',
#   'https://support.apple.com/en-us/HT204030.'),
#  ('following',
#   'these',
#   'instructions:',
#   'https://support.apple.com/en-us/HT204030.',
#   'Apple'),
#  ('these',
#   'instructions:',
#   'https://support.apple.com/en-us/HT204030.',
#   'Apple',
#   'will'),
#  ('instructions:',
#   'https://support.apple.com/en-us/HT204030.',
#   'Apple',
#   'will',
#   'charge'),
#  ('https://support.apple.com/en-us/HT204030.',
#   'Apple',
#   'will',
#   'charge',
#   'your'),
#  ('Apple', 'will', 'charge', 'your', 'payment'),
#  ('will', 'charge', 'your', 'payment', 'method'),
#  ('charge', 'your', 'payment', 'method', '(such'),
#  ('your', 'payment', 'method', '(such', 'as'),
#  ('payment', 'method', '(such', 'as', 'your'),
#  ('method', '(such', 'as', 'your', 'credit'),
#  ('(such', 'as', 'your', 'credit', 'card,'),
#  ('as', 'your', 'credit', 'card,', 'debit'),
#  ('your', 'credit', 'card,', 'debit', 'card,'),
#  ('credit', 'card,', 'debit', 'card,', 'gift'),
#  ('card,', 'debit', 'card,', 'gift', 'card/code,'),
#  ('debit', 'card,', 'gift', 'card/code,', 'or'),
#  ('card,', 'gift', 'card/code,', 'or', 'other'),
#  ('gift', 'card/code,', 'or', 'other', 'method'),
#  ('card/code,', 'or', 'other', 'method', 'available'),
#  ('or', 'other', 'method', 'available', 'in'),
#  ('other', 'method', 'available', 'in', 'your'),
#  ('method', 'available', 'in', 'your', 'Home'),
#  ('available', 'in', 'your', 'Home', 'Country)'),
#  ('in', 'your', 'Home', 'Country)', 'for'),
#  ('your', 'Home', 'Country)', 'for', 'any'),
#  ('Home', 'Country)', 'for', 'any', 'paid'),
#  ('Country)', 'for', 'any', 'paid', 'Transactions,'),
#  ('for', 'any', 'paid', 'Transactions,', 'including'),
#  ('any', 'paid', 'Transactions,', 'including', 'any'),
#  ('paid', 'Transactions,', 'including', 'any', 'applicable'),
#  ('Transactions,', 'including', 'any', 'applicable', 'taxes.'),
#  ('including', 'any', 'applicable', 'taxes.', 'If'),
#  ('any', 'applicable', 'taxes.', 'If', 'you'),
#  ('applicable', 'taxes.', 'If', 'you', 'pre-order'),
#  ('taxes.', 'If', 'you', 'pre-order', 'Content,'),
#  ('If', 'you', 'pre-order', 'Content,', 'you'),
#  ('you', 'pre-order', 'Content,', 'you', 'will'),
#  ('pre-order', 'Content,', 'you', 'will', 'be'),
#  ('Content,', 'you', 'will', 'be', 'charged'),
#  ('you', 'will', 'be', 'charged', 'when'),
#  ('will', 'be', 'charged', 'when', 'the'),
#  ('be', 'charged', 'when', 'the', 'Content'),
#  ('charged', 'when', 'the', 'Content', 'is'),
#  ('when', 'the', 'Content', 'is', 'delivered'),
#  ('the', 'Content', 'is', 'delivered', 'to'),
#  ('Content', 'is', 'delivered', 'to', 'you'),
#  ('is', 'delivered', 'to', 'you', '(unless'),
#  ('delivered', 'to', 'you', '(unless', 'you'),
#  ('to', 'you', '(unless', 'you', 'cancel'),
#  ('you', '(unless', 'you', 'cancel', 'prior'),
#  ('(unless', 'you', 'cancel', 'prior', 'to'),
#  ('you', 'cancel', 'prior', 'to', 'the'),
#  ('cancel', 'prior', 'to', 'the', 'Content’s'),
#  ('prior', 'to', 'the', 'Content’s', 'availability).'),
#  ('to', 'the', 'Content’s', 'availability).', 'In'),
#  ('the', 'Content’s', 'availability).', 'In', 'accordance'),
#  ('Content’s', 'availability).', 'In', 'accordance', 'with'),
#  ('availability).', 'In', 'accordance', 'with', 'local'),
#  ('In', 'accordance', 'with', 'local', 'law,'),
#  ('accordance', 'with', 'local', 'law,', 'Apple'),
#  ('with', 'local', 'law,', 'Apple', 'may'),
#  ('local', 'law,', 'Apple', 'may', 'update'),
#  ('law,', 'Apple', 'may', 'update', 'information'),
#  ('Apple', 'may', 'update', 'information', 'regarding'),
#  ('may', 'update', 'information', 'regarding', 'your'),
#  ('update', 'information', 'regarding', 'your', 'payment'),
#  ('information', 'regarding', 'your', 'payment', 'method'),
#  ('regarding', 'your', 'payment', 'method', 'if'),
#  ('your', 'payment', 'method', 'if', 'provided'),
#  ('payment', 'method', 'if', 'provided', 'such'),
#  ('method', 'if', 'provided', 'such', 'information'),
#  ('if', 'provided', 'such', 'information', 'by'),
#  ('provided', 'such', 'information', 'by', 'your'),
#  ('such', 'information', 'by', 'your', 'financial'),
#  ('information', 'by', 'your', 'financial', 'institution.'),
#  ('by', 'your', 'financial', 'institution.', 'For'),
#  ('your', 'financial', 'institution.', 'For', 'details'),
#  ('financial', 'institution.', 'For', 'details', 'about'),
#  ('institution.', 'For', 'details', 'about', 'how'),
#  ('For', 'details', 'about', 'how', 'Transactions'),
#  ('details', 'about', 'how', 'Transactions', 'are'),
#  ('about', 'how', 'Transactions', 'are', 'billed,'),
#  ('how', 'Transactions', 'are', 'billed,', 'please'),
#  ('Transactions', 'are', 'billed,', 'please', 'visit'),
#  ('are', 'billed,', 'please', 'visit', 'http://support.apple.com/kb/HT5582.'),
#  ('billed,', 'please', 'visit', 'http://support.apple.com/kb/HT5582.', 'All'),
#  ('please',
#   'visit',
#   'http://support.apple.com/kb/HT5582.',
#   'All',
#   'Transactions'),
#  ('visit',
#   'http://support.apple.com/kb/HT5582.',
#   'All',
#   'Transactions',
#   'are'),
#  ('http://support.apple.com/kb/HT5582.',
#   'All',
#   'Transactions',
#   'are',
#   'final.'),
#  ('All', 'Transactions', 'are', 'final.', 'Content'),
#  ('Transactions', 'are', 'final.', 'Content', 'prices'),
#  ('are', 'final.', 'Content', 'prices', 'may'),
#  ('final.', 'Content', 'prices', 'may', 'change'),
#  ('Content', 'prices', 'may', 'change', 'at'),
#  ('prices', 'may', 'change', 'at', 'any'),
#  ('may', 'change', 'at', 'any', 'time.'),
#  ('change', 'at', 'any', 'time.', 'If'),
#  ('at', 'any', 'time.', 'If', 'technical'),
#  ('any', 'time.', 'If', 'technical', 'problems'),
#  ('time.', 'If', 'technical', 'problems', 'prevent'),
#  ('If', 'technical', 'problems', 'prevent', 'or'),
#  ('technical', 'problems', 'prevent', 'or', 'unreasonably'),
#  ('problems', 'prevent', 'or', 'unreasonably', 'delay'),
#  ('prevent', 'or', 'unreasonably', 'delay', 'delivery'),
#  ('or', 'unreasonably', 'delay', 'delivery', 'of'),
#  ('unreasonably', 'delay', 'delivery', 'of', 'Content,'),
#  ('delay', 'delivery', 'of', 'Content,', 'your'),
#  ('delivery', 'of', 'Content,', 'your', 'exclusive'),
#  ('of', 'Content,', 'your', 'exclusive', 'and'),
#  ('Content,', 'your', 'exclusive', 'and', 'sole'),
#  ('your', 'exclusive', 'and', 'sole', 'remedy'),
#  ('exclusive', 'and', 'sole', 'remedy', 'is'),
#  ('and', 'sole', 'remedy', 'is', 'either'),
#  ('sole', 'remedy', 'is', 'either', 'replacement'),
#  ('remedy', 'is', 'either', 'replacement', 'of'),
#  ('is', 'either', 'replacement', 'of', 'the'),
#  ('either', 'replacement', 'of', 'the', 'Content'),
#  ('replacement', 'of', 'the', 'Content', 'or'),
#  ('of', 'the', 'Content', 'or', 'refund'),
#  ('the', 'Content', 'or', 'refund', 'of'),
#  ('Content', 'or', 'refund', 'of', 'the'),
#  ('or', 'refund', 'of', 'the', 'price'),
#  ('refund', 'of', 'the', 'price', 'paid,'),
#  ('of', 'the', 'price', 'paid,', 'as'),
#  ('the', 'price', 'paid,', 'as', 'determined'),
#  ('price', 'paid,', 'as', 'determined', 'by'),
#  ('paid,', 'as', 'determined', 'by', 'Apple.'),
#  ('as', 'determined', 'by', 'Apple.', 'From'),
#  ('determined', 'by', 'Apple.', 'From', 'time'),
#  ('by', 'Apple.', 'From', 'time', 'to'),
#  ('Apple.', 'From', 'time', 'to', 'time,'),
#  ('From', 'time', 'to', 'time,', 'Apple'),
#  ('time', 'to', 'time,', 'Apple', 'may'),
#  ('to', 'time,', 'Apple', 'may', 'refuse'),
#  ('time,', 'Apple', 'may', 'refuse', 'a'),
#  ('Apple', 'may', 'refuse', 'a', 'refund'),
#  ('may', 'refuse', 'a', 'refund', 'request'),
#  ('refuse', 'a', 'refund', 'request', 'if'),
#  ('a', 'refund', 'request', 'if', 'we'),
#  ('refund', 'request', 'if', 'we', 'find'),
#  ('request', 'if', 'we', 'find', 'evidence'),
#  ('if', 'we', 'find', 'evidence', 'of'),
#  ('we', 'find', 'evidence', 'of', 'fraud,'),
#  ('find', 'evidence', 'of', 'fraud,', 'refund'),
#  ('evidence', 'of', 'fraud,', 'refund', 'abuse,'),
#  ('of', 'fraud,', 'refund', 'abuse,', 'or'),
#  ('fraud,', 'refund', 'abuse,', 'or', 'other'),
#  ('refund', 'abuse,', 'or', 'other', 'manipulative'),
#  ('abuse,', 'or', 'other', 'manipulative', 'behavior'),
#  ('or', 'other', 'manipulative', 'behavior', 'that'),
#  ('other', 'manipulative', 'behavior', 'that', 'entitles'),
#  ('manipulative', 'behavior', 'that', 'entitles', 'Apple'),
#  ('behavior', 'that', 'entitles', 'Apple', 'to'),
#  ('that', 'entitles', 'Apple', 'to', 'a'),
#  ('entitles', 'Apple', 'to', 'a', 'corresponding'),
#  ('Apple', 'to', 'a', 'corresponding', 'counterclaim.'),
#  ('to', 'a', 'corresponding', 'counterclaim.', 'Terms'),
#  ('a', 'corresponding', 'counterclaim.', 'Terms', 'related'),
#  ('corresponding', 'counterclaim.', 'Terms', 'related', 'to'),
#  ('counterclaim.', 'Terms', 'related', 'to', 'gift'),
#  ('Terms', 'related', 'to', 'gift', 'cards/codes'),
#  ('related', 'to', 'gift', 'cards/codes', 'are'),
#  ('to', 'gift', 'cards/codes', 'are', 'available'),
#  ('gift', 'cards/codes', 'are', 'available', 'here:'),
#  ('cards/codes',
#   'are',
#   'available',
#   'here:',
#   'https://www.apple.com/legal/internet-services/itunes/giftcards/.'),
#  ('are',
#   'available',
#   'here:',
#   'https://www.apple.com/legal/internet-services/itunes/giftcards/.',
#   'APPLE'),
#  ('available',
#   'here:',
#   'https://www.apple.com/legal/internet-services/itunes/giftcards/.',
#   'APPLE',
#   'ID'),
#  ('here:',
#   'https://www.apple.com/legal/internet-services/itunes/giftcards/.',
#   'APPLE',
#   'ID',
#   'Using'),
#  ('https://www.apple.com/legal/internet-services/itunes/giftcards/.',
#   'APPLE',
#   'ID',
#   'Using',
#   'our'),
#  ('APPLE', 'ID', 'Using', 'our', 'Services'),
#  ('ID', 'Using', 'our', 'Services', 'and'),
#  ('Using', 'our', 'Services', 'and', 'accessing'),
#  ('our', 'Services', 'and', 'accessing', 'your'),
#  ('Services', 'and', 'accessing', 'your', 'Content'),
#  ('and', 'accessing', 'your', 'Content', 'requires'),
#  ('accessing', 'your', 'Content', 'requires', 'an'),
#  ('your', 'Content', 'requires', 'an', 'Apple'),
#  ('Content', 'requires', 'an', 'Apple', 'ID.'),
#  ('requires', 'an', 'Apple', 'ID.', 'An'),
#  ('an', 'Apple', 'ID.', 'An', 'Apple'),
#  ('Apple', 'ID.', 'An', 'Apple', 'ID'),
#  ('ID.', 'An', 'Apple', 'ID', 'is'),
#  ('An', 'Apple', 'ID', 'is', 'the'),
#  ('Apple', 'ID', 'is', 'the', 'account'),
#  ('ID', 'is', 'the', 'account', 'you'),
#  ('is', 'the', 'account', 'you', 'use'),
#  ('the', 'account', 'you', 'use', 'across'),
#  ('account', 'you', 'use', 'across', 'Apple’s'),
#  ('you', 'use', 'across', 'Apple’s', 'ecosystem.'),
#  ('use', 'across', 'Apple’s', 'ecosystem.', 'Your'),
#  ('across', 'Apple’s', 'ecosystem.', 'Your', 'Apple'),
#  ('Apple’s', 'ecosystem.', 'Your', 'Apple', 'ID'),
#  ('ecosystem.', 'Your', 'Apple', 'ID', 'is'),
#  ('Your', 'Apple', 'ID', 'is', 'valuable,'),
#  ('Apple', 'ID', 'is', 'valuable,', 'and'),
#  ('ID', 'is', 'valuable,', 'and', 'you'),
#  ('is', 'valuable,', 'and', 'you', 'are'),
#  ('valuable,', 'and', 'you', 'are', 'responsible'),
#  ('and', 'you', 'are', 'responsible', 'for'),
#  ('you', 'are', 'responsible', 'for', 'maintaining'),
#  ('are', 'responsible', 'for', 'maintaining', 'its'),
#  ('responsible', 'for', 'maintaining', 'its', 'confidentiality'),
#  ('for', 'maintaining', 'its', 'confidentiality', 'and'),
#  ('maintaining', 'its', 'confidentiality', 'and', 'security.'),
#  ('its', 'confidentiality', 'and', 'security.', 'Apple'),
#  ('confidentiality', 'and', 'security.', 'Apple', 'is'),
#  ('and', 'security.', 'Apple', 'is', 'not'),
#  ('security.', 'Apple', 'is', 'not', 'responsible'),
#  ('Apple', 'is', 'not', 'responsible', 'for'),
#  ('is', 'not', 'responsible', 'for', 'any'),
#  ('not', 'responsible', 'for', 'any', 'losses'),
#  ('responsible', 'for', 'any', 'losses', 'arising'),
#  ('for', 'any', 'losses', 'arising', 'from'),
#  ('any', 'losses', 'arising', 'from', 'the'),
#  ('losses', 'arising', 'from', 'the', 'unauthorized'),
#  ('arising', 'from', 'the', 'unauthorized', 'use'),
#  ('from', 'the', 'unauthorized', 'use', 'of'),
#  ('the', 'unauthorized', 'use', 'of', 'your'),
#  ('unauthorized', 'use', 'of', 'your', 'Apple'),
#  ('use', 'of', 'your', 'Apple', 'ID.'),
#  ('of', 'your', 'Apple', 'ID.', 'Please'),
#  ('your', 'Apple', 'ID.', 'Please', 'contact'),
#  ('Apple', 'ID.', 'Please', 'contact', 'Apple'),
#  ('ID.', 'Please', 'contact', 'Apple', 'if'),
#  ('Please', 'contact', 'Apple', 'if', 'you'),
#  ('contact', 'Apple', 'if', 'you', 'suspect'),
#  ('Apple', 'if', 'you', 'suspect', 'that'),
#  ('if', 'you', 'suspect', 'that', 'your'),
#  ('you', 'suspect', 'that', 'your', 'Apple'),
#  ('suspect', 'that', 'your', 'Apple', 'ID'),
#  ('that', 'your', 'Apple', 'ID', 'has'),
#  ('your', 'Apple', 'ID', 'has', 'been'),
#  ('Apple', 'ID', 'has', 'been', 'compromised.'),
#  ('ID', 'has', 'been', 'compromised.', 'You'),
#  ('has', 'been', 'compromised.', 'You', 'must'),
#  ('been', 'compromised.', 'You', 'must', 'be'),
#  ('compromised.', 'You', 'must', 'be', 'age'),
#  ('You', 'must', 'be', 'age', '13'),
#  ('must', 'be', 'age', '13', '(or'),
#  ('be', 'age', '13', '(or', 'equivalent'),
#  ('age', '13', '(or', 'equivalent', 'minimum'),
#  ('13', '(or', 'equivalent', 'minimum', 'age'),
#  ('(or', 'equivalent', 'minimum', 'age', 'in'),
#  ('equivalent', 'minimum', 'age', 'in', 'your'),
#  ('minimum', 'age', 'in', 'your', 'Home'),
#  ('age', 'in', 'your', 'Home', 'Country,'),
#  ('in', 'your', 'Home', 'Country,', 'as'),
#  ('your', 'Home', 'Country,', 'as', 'set'),
#  ('Home', 'Country,', 'as', 'set', 'forth'),
#  ('Country,', 'as', 'set', 'forth', 'in'),
#  ('as', 'set', 'forth', 'in', 'the'),
#  ('set', 'forth', 'in', 'the', 'registration'),
#  ('forth', 'in', 'the', 'registration', 'process)'),
#  ('in', 'the', 'registration', 'process)', 'to'),
#  ('the', 'registration', 'process)', 'to', 'create'),
#  ('registration', 'process)', 'to', 'create', 'an'),
#  ('process)', 'to', 'create', 'an', 'Apple'),
#  ('to', 'create', 'an', 'Apple', 'ID'),
#  ('create', 'an', 'Apple', 'ID', 'and'),
#  ('an', 'Apple', 'ID', 'and', 'use'),
#  ('Apple', 'ID', 'and', 'use', 'our'),
#  ('ID', 'and', 'use', 'our', 'Services.'),
#  ('and', 'use', 'our', 'Services.', 'Apple'),
#  ('use', 'our', 'Services.', 'Apple', 'IDs'),
#  ('our', 'Services.', 'Apple', 'IDs', 'for'),
#  ('Services.', 'Apple', 'IDs', 'for', 'persons'),
#  ('Apple', 'IDs', 'for', 'persons', 'under'),
#  ('IDs', 'for', 'persons', 'under', 'this'),
#  ('for', 'persons', 'under', 'this', 'age'),
#  ('persons', 'under', 'this', 'age', 'can'),
#  ('under', 'this', 'age', 'can', 'be'),
#  ('this', 'age', 'can', 'be', 'created'),
#  ('age', 'can', 'be', 'created', 'by'),
#  ('can', 'be', 'created', 'by', 'a'),
#  ('be', 'created', 'by', 'a', 'parent'),
#  ('created', 'by', 'a', 'parent', 'or'),
#  ('by', 'a', 'parent', 'or', 'legal'),
#  ('a', 'parent', 'or', 'legal', 'guardian'),
#  ('parent', 'or', 'legal', 'guardian', 'using'),
#  ('or', 'legal', 'guardian', 'using', 'Family'),
#  ('legal', 'guardian', 'using', 'Family', 'Sharing'),
#  ('guardian', 'using', 'Family', 'Sharing', 'or'),
#  ('using', 'Family', 'Sharing', 'or', 'by'),
#  ('Family', 'Sharing', 'or', 'by', 'an'),
#  ('Sharing', 'or', 'by', 'an', 'approved'),
#  ('or', 'by', 'an', 'approved', 'educational'),
#  ('by', 'an', 'approved', 'educational', 'institution.'),
#  ('an', 'approved', 'educational', 'institution.', 'PRIVACY'),
#  ('approved', 'educational', 'institution.', 'PRIVACY', 'Your'),
#  ('educational', 'institution.', 'PRIVACY', 'Your', 'use'),
#  ('institution.', 'PRIVACY', 'Your', 'use', 'of'),
#  ('PRIVACY', 'Your', 'use', 'of', 'our'),
#  ('Your', 'use', 'of', 'our', 'Services'),
#  ('use', 'of', 'our', 'Services', 'is'),
#  ('of', 'our', 'Services', 'is', 'subject'),
#  ('our', 'Services', 'is', 'subject', 'to'),
#  ('Services', 'is', 'subject', 'to', 'Apple’s'),
#  ('is', 'subject', 'to', 'Apple’s', 'Privacy'),
#  ('subject', 'to', 'Apple’s', 'Privacy', 'Policy,'),
#  ('to', 'Apple’s', 'Privacy', 'Policy,', 'which'),
#  ('Apple’s', 'Privacy', 'Policy,', 'which', 'is'),
#  ('Privacy', 'Policy,', 'which', 'is', 'available'),
#  ('Policy,', 'which', 'is', 'available', 'at'),
#  ('which', 'is', 'available', 'at', 'https://www.apple.com/legal/privacy/.'),
#  ('is',
#   'available',
#   'at',
#   'https://www.apple.com/legal/privacy/.',
#   'SERVICES'),
#  ('available',
#   'at',
#   'https://www.apple.com/legal/privacy/.',
#   'SERVICES',
#   'AND'),
#  ('at', 'https://www.apple.com/legal/privacy/.', 'SERVICES', 'AND', 'CONTENT'),
#  ('https://www.apple.com/legal/privacy/.',
#   'SERVICES',
#   'AND',
#   'CONTENT',
#   'USAGE'),
#  ('SERVICES', 'AND', 'CONTENT', 'USAGE', 'RULES'),
#  ('AND', 'CONTENT', 'USAGE', 'RULES', 'Your'),
#  ('CONTENT', 'USAGE', 'RULES', 'Your', 'use'),
#  ('USAGE', 'RULES', 'Your', 'use', 'of'),
#  ('RULES', 'Your', 'use', 'of', 'the'),
#  ('Your', 'use', 'of', 'the', 'Services'),
#  ('use', 'of', 'the', 'Services', 'and'),
#  ('of', 'the', 'Services', 'and', 'Content'),
#  ('the', 'Services', 'and', 'Content', 'must'),
#  ('Services', 'and', 'Content', 'must', 'follow'),
#  ('and', 'Content', 'must', 'follow', 'the'),
#  ('Content', 'must', 'follow', 'the', 'rules'),
#  ('must', 'follow', 'the', 'rules', 'set'),
#  ('follow', 'the', 'rules', 'set', 'forth'),
#  ('the', 'rules', 'set', 'forth', 'in'),
#  ('rules', 'set', 'forth', 'in', 'this'),
#  ('set', 'forth', 'in', 'this', 'section'),
#  ('forth', 'in', 'this', 'section', '(“Usage'),
#  ('in', 'this', 'section', '(“Usage', 'Rules”).'),
#  ('this', 'section', '(“Usage', 'Rules”).', 'Any'),
#  ('section', '(“Usage', 'Rules”).', 'Any', 'other'),
#  ('(“Usage', 'Rules”).', 'Any', 'other', 'use'),
#  ('Rules”).', 'Any', 'other', 'use', 'of'),
#  ('Any', 'other', 'use', 'of', 'the'),
#  ('other', 'use', 'of', 'the', 'Services'),
#  ('use', 'of', 'the', 'Services', 'and'),
#  ('of', 'the', 'Services', 'and', 'Content'),
#  ('the', 'Services', 'and', 'Content', 'is'),
#  ('Services', 'and', 'Content', 'is', 'a'),
#  ('and', 'Content', 'is', 'a', 'material'),
#  ('Content', 'is', 'a', 'material', 'breach'),
#  ('is', 'a', 'material', 'breach', 'of'),
#  ('a', 'material', 'breach', 'of', 'this'),
#  ('material', 'breach', 'of', 'this', 'Agreement.'),
#  ('breach', 'of', 'this', 'Agreement.', 'Apple'),
#  ('of', 'this', 'Agreement.', 'Apple', 'may'),
#  ('this', 'Agreement.', 'Apple', 'may', 'monitor'),
#  ('Agreement.', 'Apple', 'may', 'monitor', 'your'),
#  ('Apple', 'may', 'monitor', 'your', 'use'),
#  ('may', 'monitor', 'your', 'use', 'of'),
#  ('monitor', 'your', 'use', 'of', 'the'),
#  ('your', 'use', 'of', 'the', 'Services'),
#  ('use', 'of', 'the', 'Services', 'and'),
#  ('of', 'the', 'Services', 'and', 'Content'),
#  ('the', 'Services', 'and', 'Content', 'to'),
#  ('Services', 'and', 'Content', 'to', 'ensure'),
#  ('and', 'Content', 'to', 'ensure', 'that'),
#  ('Content', 'to', 'ensure', 'that', 'you'),
#  ('to', 'ensure', 'that', 'you', 'are'),
#  ('ensure', 'that', 'you', 'are', 'following'),
#  ('that', 'you', 'are', 'following', 'these'),
#  ('you', 'are', 'following', 'these', 'Usage'),
#  ('are', 'following', 'these', 'Usage', 'Rules.'),
#  ('following', 'these', 'Usage', 'Rules.', 'All'),
#  ('these', 'Usage', 'Rules.', 'All', 'Services:'),
#  ('Usage', 'Rules.', 'All', 'Services:', '-'),
#  ('Rules.', 'All', 'Services:', '-', 'You'),
#  ('All', 'Services:', '-', 'You', 'may'),
#  ('Services:', '-', 'You', 'may', 'use'),
#  ('-', 'You', 'may', 'use', 'the'),
#  ('You', 'may', 'use', 'the', 'Services'),
#  ('may', 'use', 'the', 'Services', 'and'),
#  ('use', 'the', 'Services', 'and', 'Content'),
#  ('the', 'Services', 'and', 'Content', 'only'),
#  ('Services', 'and', 'Content', 'only', 'for'),
#  ('and', 'Content', 'only', 'for', 'personal,'),
#  ('Content', 'only', 'for', 'personal,', 'noncommercial'),
#  ('only', 'for', 'personal,', 'noncommercial', 'purposes'),
#  ('for', 'personal,', 'noncommercial', 'purposes', '(except'),
#  ('personal,', 'noncommercial', 'purposes', '(except', 'as'),
#  ('noncommercial', 'purposes', '(except', 'as', 'set'),
#  ('purposes', '(except', 'as', 'set', 'forth'),
#  ('(except', 'as', 'set', 'forth', 'in'),
#  ('as', 'set', 'forth', 'in', 'the'),
#  ('set', 'forth', 'in', 'the', 'App'),
#  ('forth', 'in', 'the', 'App', 'Store'),
#  ('in', 'the', 'App', 'Store', 'Content'),
#  ('the', 'App', 'Store', 'Content', 'section'),
#  ('App', 'Store', 'Content', 'section', 'below).'),
#  ('Store', 'Content', 'section', 'below).', '-'),
#  ('Content', 'section', 'below).', '-', 'Apple’s'),
#  ('section', 'below).', '-', 'Apple’s', 'delivery'),
#  ('below).', '-', 'Apple’s', 'delivery', 'of'),
#  ('-', 'Apple’s', 'delivery', 'of', 'Content'),
#  ('Apple’s', 'delivery', 'of', 'Content', 'does'),
#  ('delivery', 'of', 'Content', 'does', 'not'),
#  ('of', 'Content', 'does', 'not', 'transfer'),
#  ('Content', 'does', 'not', 'transfer', 'any'),
#  ('does', 'not', 'transfer', 'any', 'promotional'),
#  ('not', 'transfer', 'any', 'promotional', 'use'),
#  ('transfer', 'any', 'promotional', 'use', 'rights'),
#  ('any', 'promotional', 'use', 'rights', 'to'),
#  ('promotional', 'use', 'rights', 'to', 'you,'),
#  ('use', 'rights', 'to', 'you,', 'and'),
#  ('rights', 'to', 'you,', 'and', 'does'),
#  ('to', 'you,', 'and', 'does', 'not'),
#  ('you,', 'and', 'does', 'not', 'constitute'),
#  ('and', 'does', 'not', 'constitute', 'a'),
#  ('does', 'not', 'constitute', 'a', 'grant'),
#  ('not', 'constitute', 'a', 'grant', 'or'),
#  ('constitute', 'a', 'grant', 'or', 'waiver'),
#  ('a', 'grant', 'or', 'waiver', 'of'),
#  ('grant', 'or', 'waiver', 'of', 'any'),
#  ('or', 'waiver', 'of', 'any', 'rights'),
#  ('waiver', 'of', 'any', 'rights', 'of'),
#  ('of', 'any', 'rights', 'of', 'the'),
#  ('any', 'rights', 'of', 'the', 'copyright'),
#  ('rights', 'of', 'the', 'copyright', 'owners.'),
#  ('of', 'the', 'copyright', 'owners.', '-'),
#  ('the', 'copyright', 'owners.', '-', 'You'),
#  ('copyright', 'owners.', '-', 'You', 'can'),
#  ('owners.', '-', 'You', 'can', 'use'),
#  ('-', 'You', 'can', 'use', 'Content'),
#  ('You', 'can', 'use', 'Content', 'from'),
#  ('can', 'use', 'Content', 'from', 'up'),
#  ('use', 'Content', 'from', 'up', 'to'),
#  ('Content', 'from', 'up', 'to', 'five'),
#  ('from', 'up', 'to', 'five', 'different'),
#  ('up', 'to', 'five', 'different', 'Apple'),
#  ('to', 'five', 'different', 'Apple', 'IDs'),
#  ('five', 'different', 'Apple', 'IDs', 'on'),
#  ('different', 'Apple', 'IDs', 'on', 'each'),
#  ('Apple', 'IDs', 'on', 'each', 'device.'),
#  ('IDs', 'on', 'each', 'device.', '-'),
#  ('on', 'each', 'device.', '-', 'It'),
#  ('each', 'device.', '-', 'It', 'is'),
#  ('device.', '-', 'It', 'is', 'your'),
#  ('-', 'It', 'is', 'your', 'responsibility'),
#  ('It', 'is', 'your', 'responsibility', 'not'),
#  ('is', 'your', 'responsibility', 'not', 'to'),
#  ('your', 'responsibility', 'not', 'to', 'lose,'),
#  ('responsibility', 'not', 'to', 'lose,', 'destroy,'),
#  ('not', 'to', 'lose,', 'destroy,', 'or'),
#  ('to', 'lose,', 'destroy,', 'or', 'damage'),
#  ('lose,', 'destroy,', 'or', 'damage', 'Content'),
#  ('destroy,', 'or', 'damage', 'Content', 'once'),
#  ('or', 'damage', 'Content', 'once', 'downloaded.'),
#  ('damage', 'Content', 'once', 'downloaded.', 'We'),
#  ('Content', 'once', 'downloaded.', 'We', 'encourage'),
#  ('once', 'downloaded.', 'We', 'encourage', 'you'),
#  ('downloaded.', 'We', 'encourage', 'you', 'to'),
#  ('We', 'encourage', 'you', 'to', 'back'),
#  ('encourage', 'you', 'to', 'back', 'up'),
#  ('you', 'to', 'back', 'up', 'your'),
#  ('to', 'back', 'up', 'your', 'Content'),
#  ('back', 'up', 'your', 'Content', 'regularly.'),
#  ('up', 'your', 'Content', 'regularly.', '-'),
#  ('your', 'Content', 'regularly.', '-', 'You'),
#  ('Content', 'regularly.', '-', 'You', 'may'),
#  ('regularly.', '-', 'You', 'may', 'not'),
#  ('-', 'You', 'may', 'not', 'tamper'),
#  ('You', 'may', 'not', 'tamper', 'with'),
#  ('may', 'not', 'tamper', 'with', 'or'),
#  ('not', 'tamper', 'with', 'or', 'circumvent'),
#  ('tamper', 'with', 'or', 'circumvent', 'any'),
#  ('with', 'or', 'circumvent', 'any', 'security'),
#  ('or', 'circumvent', 'any', 'security', 'technology'),
#  ('circumvent', 'any', 'security', 'technology', 'included'),
#  ('any', 'security', 'technology', 'included', 'with'),
#  ('security', 'technology', 'included', 'with', 'the'),
#  ('technology', 'included', 'with', 'the', 'Services.'),
#  ('included', 'with', 'the', 'Services.', '-'),
#  ('with', 'the', 'Services.', '-', 'You'),
#  ('the', 'Services.', '-', 'You', 'may'),
#  ('Services.', '-', 'You', 'may', 'access'),
#  ('-', 'You', 'may', 'access', 'our'),
#  ('You', 'may', 'access', 'our', 'Services'),
#  ('may', 'access', 'our', 'Services', 'only'),
#  ('access', 'our', 'Services', 'only', 'using'),
#  ('our', 'Services', 'only', 'using', 'Apple’s'),
#  ('Services', 'only', 'using', 'Apple’s', 'software,'),
#  ('only', 'using', 'Apple’s', 'software,', 'and'),
#  ('using', 'Apple’s', 'software,', 'and', 'may'),
#  ('Apple’s', 'software,', 'and', 'may', 'not'),
#  ('software,', 'and', 'may', 'not', 'modify'),
#  ('and', 'may', 'not', 'modify', 'or'),
#  ('may', 'not', 'modify', 'or', 'use'),
#  ('not', 'modify', 'or', 'use', 'modified'),
#  ('modify', 'or', 'use', 'modified', 'versions'),
#  ('or', 'use', 'modified', 'versions', 'of'),
#  ('use', 'modified', 'versions', 'of', 'such'),
#  ('modified', 'versions', 'of', 'such', 'software.'),
#  ('versions', 'of', 'such', 'software.', '-'),
#  ('of', 'such', 'software.', '-', 'Video'),
#  ('such', 'software.', '-', 'Video', 'Content'),
#  ('software.', '-', 'Video', 'Content', 'requires'),
#  ('-', 'Video', 'Content', 'requires', 'an'),
#  ('Video', 'Content', 'requires', 'an', 'HDCP'),
#  ('Content', 'requires', 'an', 'HDCP', 'connection.'),
#  ('requires', 'an', 'HDCP', 'connection.', 'iTunes'),
#  ('an', 'HDCP', 'connection.', 'iTunes', 'Store'),
#  ('HDCP', 'connection.', 'iTunes', 'Store', 'Content:'),
#  ('connection.', 'iTunes', 'Store', 'Content:', '-'),
#  ('iTunes', 'Store', 'Content:', '-', 'You'),
#  ('Store', 'Content:', '-', 'You', 'can'),
#  ('Content:', '-', 'You', 'can', 'use'),
#  ('-', 'You', 'can', 'use', 'Digital'),
#  ('You', 'can', 'use', 'Digital', 'Rights'),
#  ('can', 'use', 'Digital', 'Rights', 'Management'),
#  ('use', 'Digital', 'Rights', 'Management', '(DRM)-free'),
#  ('Digital', 'Rights', 'Management', '(DRM)-free', 'Content'),
#  ('Rights', 'Management', '(DRM)-free', 'Content', 'on'),
#  ('Management', '(DRM)-free', 'Content', 'on', 'a'),
#  ('(DRM)-free', 'Content', 'on', 'a', 'reasonable'),
#  ('Content', 'on', 'a', 'reasonable', 'number'),
#  ('on', 'a', 'reasonable', 'number', 'of'),
#  ('a', 'reasonable', 'number', 'of', 'compatible'),
#  ('reasonable', 'number', 'of', 'compatible', 'devices'),
#  ('number', 'of', 'compatible', 'devices', 'that'),
#  ('of', 'compatible', 'devices', 'that', 'you'),
#  ('compatible', 'devices', 'that', 'you', 'own'),
#  ('devices', 'that', 'you', 'own', 'or'),
#  ('that', 'you', 'own', 'or', 'control.'),
#  ('you', 'own', 'or', 'control.', 'DRM-protected'),
#  ('own', 'or', 'control.', 'DRM-protected', 'Content'),
#  ('or', 'control.', 'DRM-protected', 'Content', 'can'),
#  ('control.', 'DRM-protected', 'Content', 'can', 'be'),
#  ('DRM-protected', 'Content', 'can', 'be', 'used'),
#  ('Content', 'can', 'be', 'used', 'on'),
#  ('can', 'be', 'used', 'on', 'up'),
#  ('be', 'used', 'on', 'up', 'to'),
#  ('used', 'on', 'up', 'to', 'five'),
#  ('on', 'up', 'to', 'five', 'computers'),
#  ('up', 'to', 'five', 'computers', 'and'),
#  ('to', 'five', 'computers', 'and', 'any'),
#  ('five', 'computers', 'and', 'any', 'number'),
#  ('computers', 'and', 'any', 'number', 'of'),
#  ('and', 'any', 'number', 'of', 'devices'),
#  ('any', 'number', 'of', 'devices', 'that'),
#  ('number', 'of', 'devices', 'that', 'you'),
#  ('of', 'devices', 'that', 'you', 'sync'),
#  ('devices', 'that', 'you', 'sync', 'to'),
#  ('that', 'you', 'sync', 'to', 'from'),
#  ('you', 'sync', 'to', 'from', 'those'),
#  ('sync', 'to', 'from', 'those', 'computers.'),
#  ('to', 'from', 'those', 'computers.', '-'),
#  ('from', 'those', 'computers.', '-', 'Content'),
#  ('those', 'computers.', '-', 'Content', 'rentals'),
#  ('computers.', '-', 'Content', 'rentals', 'are'),
#  ('-', 'Content', 'rentals', 'are', 'viewable'),
#  ('Content', 'rentals', 'are', 'viewable', 'on'),
#  ('rentals', 'are', 'viewable', 'on', 'a'),
#  ('are', 'viewable', 'on', 'a', 'single'),
#  ('viewable', 'on', 'a', 'single', 'device'),
#  ('on', 'a', 'single', 'device', 'at'),
#  ('a', 'single', 'device', 'at', 'a'),
#  ('single', 'device', 'at', 'a', 'time,'),
#  ('device', 'at', 'a', 'time,', 'and'),
#  ('at', 'a', 'time,', 'and', 'must'),
#  ('a', 'time,', 'and', 'must', 'be'),
#  ('time,', 'and', 'must', 'be', 'played'),
#  ('and', 'must', 'be', 'played', 'within'),
#  ('must', 'be', 'played', 'within', '30'),
#  ('be', 'played', 'within', '30', 'days,'),
#  ('played', 'within', '30', 'days,', 'and'),
#  ('within', '30', 'days,', 'and', 'completed'),
#  ('30', 'days,', 'and', 'completed', 'within'),
#  ('days,', 'and', 'completed', 'within', '24'),
#  ('and', 'completed', 'within', '24', 'to'),
#  ('completed', 'within', '24', 'to', '48'),
#  ('within', '24', 'to', '48', 'hours'),
#  ('24', 'to', '48', 'hours', 'of'),
#  ('to', '48', 'hours', 'of', 'the'),
#  ('48', 'hours', 'of', 'the', 'start'),
#  ('hours', 'of', 'the', 'start', 'of'),
#  ('of', 'the', 'start', 'of', 'play'),
#  ('the', 'start', 'of', 'play', 'depending'),
#  ('start', 'of', 'play', 'depending', 'on'),
#  ('of', 'play', 'depending', 'on', 'the'),
#  ('play', 'depending', 'on', 'the', 'Content'),
#  ('depending', 'on', 'the', 'Content', 'offered'),
#  ('on', 'the', 'Content', 'offered', 'on'),
#  ('the', 'Content', 'offered', 'on', 'the'),
#  ('Content', 'offered', 'on', 'the', 'Services'),
#  ('offered', 'on', 'the', 'Services', 'in'),
#  ('on', 'the', 'Services', 'in', 'your'),
#  ('the', 'Services', 'in', 'your', 'Home'),
#  ('Services', 'in', 'your', 'Home', 'Country'),
#  ('in', 'your', 'Home', 'Country', '(stopping,'),
#  ('your', 'Home', 'Country', '(stopping,', 'pausing'),
#  ('Home', 'Country', '(stopping,', 'pausing', 'or'),
#  ('Country', '(stopping,', 'pausing', 'or', 'restarting'),
#  ('(stopping,', 'pausing', 'or', 'restarting', 'does'),
#  ('pausing', 'or', 'restarting', 'does', 'not'),
#  ('or', 'restarting', 'does', 'not', 'extend'),
#  ('restarting', 'does', 'not', 'extend', 'this'),
#  ('does', 'not', 'extend', 'this', 'period).'),
#  ('not', 'extend', 'this', 'period).', '-'),
#  ('extend', 'this', 'period).', '-', 'You'),
#  ('this', 'period).', '-', 'You', 'may'),
#  ('period).', '-', 'You', 'may', 'burn'),
#  ('-', 'You', 'may', 'burn', 'an'),
#  ('You', 'may', 'burn', 'an', 'audio'),
#  ('may', 'burn', 'an', 'audio', 'playlist'),
#  ('burn', 'an', 'audio', 'playlist', 'to'),
#  ('an', 'audio', 'playlist', 'to', 'CD'),
#  ('audio', 'playlist', 'to', 'CD', 'for'),
#  ('playlist', 'to', 'CD', 'for', 'listening'),
#  ('to', 'CD', 'for', 'listening', 'purposes'),
#  ('CD', 'for', 'listening', 'purposes', 'up'),
#  ('for', 'listening', 'purposes', 'up', 'to'),
#  ('listening', 'purposes', 'up', 'to', 'seven'),
#  ('purposes', 'up', 'to', 'seven', 'times'),
#  ('up', 'to', 'seven', 'times', '(this'),
#  ('to', 'seven', 'times', '(this', 'limitation'),
#  ('seven', 'times', '(this', 'limitation', 'does'),
#  ('times', '(this', 'limitation', 'does', 'not'),
#  ('(this', 'limitation', 'does', 'not', 'apply'),
#  ('limitation', 'does', 'not', 'apply', 'to'),
#  ('does', 'not', 'apply', 'to', 'DRM-free'),
#  ('not', 'apply', 'to', 'DRM-free', 'Content).'),
#  ('apply', 'to', 'DRM-free', 'Content).', 'App'),
#  ('to', 'DRM-free', 'Content).', 'App', 'Store'),
#  ('DRM-free', 'Content).', 'App', 'Store', 'Content:'),
#  ('Content).', 'App', 'Store', 'Content:', '-'),
#  ('App', 'Store', 'Content:', '-', 'The'),
#  ('Store', 'Content:', '-', 'The', 'term'),
#  ('Content:', '-', 'The', 'term', '“App”'),
#  ('-', 'The', 'term', '“App”', 'includes'),
#  ('The', 'term', '“App”', 'includes', 'apps,'),
#  ('term', '“App”', 'includes', 'apps,', 'iMessage'),
#  ('“App”', 'includes', 'apps,', 'iMessage', 'and'),
#  ('includes', 'apps,', 'iMessage', 'and', 'Apple'),
#  ('apps,', 'iMessage', 'and', 'Apple', 'Watch'),
#  ('iMessage', 'and', 'Apple', 'Watch', 'apps,'),
#  ('and', 'Apple', 'Watch', 'apps,', 'in-app'),
#  ('Apple', 'Watch', 'apps,', 'in-app', 'purchases,'),
#  ('Watch', 'apps,', 'in-app', 'purchases,', 'extensions'),
#  ('apps,', 'in-app', 'purchases,', 'extensions', '(such'),
#  ('in-app', 'purchases,', 'extensions', '(such', 'as'),
#  ('purchases,', 'extensions', '(such', 'as', 'keyboards),'),
#  ('extensions', '(such', 'as', 'keyboards),', 'stickers,'),
#  ('(such', 'as', 'keyboards),', 'stickers,', 'and'),
#  ('as', 'keyboards),', 'stickers,', 'and', 'subscriptions'),
#  ('keyboards),', 'stickers,', 'and', 'subscriptions', 'made'),
#  ('stickers,', 'and', 'subscriptions', 'made', 'available'),
#  ('and', 'subscriptions', 'made', 'available', 'in'),
#  ('subscriptions', 'made', 'available', 'in', 'an'),
#  ('made', 'available', 'in', 'an', 'app.'),
#  ('available', 'in', 'an', 'app.', '-'),
#  ('in', 'an', 'app.', '-', 'You'),
#  ('an', 'app.', '-', 'You', 'can'),
#  ('app.', '-', 'You', 'can', 'use'),
#  ('-', 'You', 'can', 'use', 'Apps'),
#  ('You', 'can', 'use', 'Apps', 'on'),
#  ('can', 'use', 'Apps', 'on', 'any'),
#  ('use', 'Apps', 'on', 'any', 'device'),
#  ('Apps', 'on', 'any', 'device', 'that'),
#  ('on', 'any', 'device', 'that', 'you'),
#  ('any', 'device', 'that', 'you', 'own'),
#  ('device', 'that', 'you', 'own', 'or'),
#  ('that', 'you', 'own', 'or', 'control.'),
#  ('you', 'own', 'or', 'control.', '-'),
#  ('own', 'or', 'control.', '-', 'Individuals'),
#  ('or', 'control.', '-', 'Individuals', 'acting'),
#  ('control.', '-', 'Individuals', 'acting', 'on'),
#  ('-', 'Individuals', 'acting', 'on', 'behalf'),
#  ('Individuals', 'acting', 'on', 'behalf', 'of'),
#  ('acting', 'on', 'behalf', 'of', 'a'),
#  ('on', 'behalf', 'of', 'a', 'commercial'),
#  ('behalf', 'of', 'a', 'commercial', 'enterprise,'),
#  ('of', 'a', 'commercial', 'enterprise,', 'governmental'),
#  ('a', 'commercial', 'enterprise,', 'governmental', 'organization'),
#  ('commercial', 'enterprise,', 'governmental', 'organization', 'or'),
#  ('enterprise,', 'governmental', 'organization', 'or', 'educational'),
#  ('governmental', 'organization', 'or', 'educational', 'institution'),
#  ('organization', 'or', 'educational', 'institution', '(an'),
#  ('or', 'educational', 'institution', '(an', '“Enterprise”)'),
#  ('educational', 'institution', '(an', '“Enterprise”)', 'may'),
#  ('institution', '(an', '“Enterprise”)', 'may', 'download'),
#  ('(an', '“Enterprise”)', 'may', 'download', 'and'),
#  ('“Enterprise”)', 'may', 'download', 'and', 'sync'),
#  ('may', 'download', 'and', 'sync', 'Apps'),
#  ('download', 'and', 'sync', 'Apps', 'for'),
#  ('and', 'sync', 'Apps', 'for', 'use'),
#  ('sync', 'Apps', 'for', 'use', 'by'),
#  ('Apps', 'for', 'use', 'by', 'either'),
#  ('for', 'use', 'by', 'either', '(i)'),
#  ('use', 'by', 'either', '(i)', 'a'),
#  ('by', 'either', '(i)', 'a', 'single'),
#  ('either', '(i)', 'a', 'single', 'individual'),
#  ('(i)', 'a', 'single', 'individual', 'on'),
#  ('a', 'single', 'individual', 'on', 'one'),
#  ('single', 'individual', 'on', 'one', 'or'),
#  ('individual', 'on', 'one', 'or', 'more'),
#  ('on', 'one', 'or', 'more', 'devices'),
#  ('one', 'or', 'more', 'devices', 'owned'),
#  ('or', 'more', 'devices', 'owned', 'or'),
#  ('more', 'devices', 'owned', 'or', 'controlled'),
#  ('devices', 'owned', 'or', 'controlled', 'by'),
#  ('owned', 'or', 'controlled', 'by', 'an'),
#  ('or', 'controlled', 'by', 'an', 'Enterprise;'),
#  ('controlled', 'by', 'an', 'Enterprise;', 'or'),
#  ('by', 'an', 'Enterprise;', 'or', '(ii)'),
#  ('an', 'Enterprise;', 'or', '(ii)', 'multiple'),
#  ('Enterprise;', 'or', '(ii)', 'multiple', 'individuals'),
#  ('or', '(ii)', 'multiple', 'individuals', 'on'),
#  ('(ii)', 'multiple', 'individuals', 'on', 'a'),
#  ('multiple', 'individuals', 'on', 'a', 'single'),
#  ('individuals', 'on', 'a', 'single', 'shared'),
#  ('on', 'a', 'single', 'shared', 'device'),
#  ('a', 'single', 'shared', 'device', 'owned'),
#  ('single', 'shared', 'device', 'owned', 'or'),
#  ('shared', 'device', 'owned', 'or', 'controlled'),
#  ('device', 'owned', 'or', 'controlled', 'by'),
#  ('owned', 'or', 'controlled', 'by', 'an'),
#  ('or', 'controlled', 'by', 'an', 'Enterprise.'),
#  ('controlled', 'by', 'an', 'Enterprise.', 'For'),
#  ('by', 'an', 'Enterprise.', 'For', 'the'),
#  ('an', 'Enterprise.', 'For', 'the', 'sake'),
#  ('Enterprise.', 'For', 'the', 'sake', 'of'),
#  ('For', 'the', 'sake', 'of', 'clarity,'),
#  ('the', 'sake', 'of', 'clarity,', 'each'),
#  ('sake', 'of', 'clarity,', 'each', 'device'),
#  ('of', 'clarity,', 'each', 'device', 'used'),
#  ('clarity,', 'each', 'device', 'used', 'serially'),
#  ('each', 'device', 'used', 'serially', 'or'),
#  ('device', 'used', 'serially', 'or', 'collectively'),
#  ('used', 'serially', 'or', 'collectively', 'by'),
#  ('serially', 'or', 'collectively', 'by', 'multiple'),
#  ('or', 'collectively', 'by', 'multiple', 'users'),
#  ...]

# %% [markdown]
# # apple terms + conditions??

# %%
def add_to_model(model, n, seq):
    # make a copy of seq and append None to the end
    seq = list(seq[:]) + [None]
    for i in range(len(seq)-n):
        # tuple because we're using it as a dict key!
        gram = tuple(seq[i:i+n])
        next_item = seq[i+n]            
        if gram not in model:
            model[gram] = []
        model[gram].append(next_item)
        
def markov_model(n, seq):
    model = {}
    add_to_model(model, n, seq)
    return model

# %%
def gen_from_model(n, model, start=None, max_gen=100):
    if start is None:
        start = random.choice(list(model.keys()))
    output = list(start)
    for i in range(max_gen):
        start = tuple(output[-n:])
        next_item = random.choice(model[start])
        if next_item is None:
            break
        else:
            output.append(next_item)
    return output

# %%
generated_words = gen_from_model(2,markov_model(2,open("terms_conditions.txt").read().lower().split()), ('terms','and'), 800)
print(' '.join(generated_words).capitalize())
# Out:
# Terms and conditions with respect to the beginning of the services may not use the external services at any time with or circumvent any security technology included with the services. apple further reserves the right to change, suspend, remove, disable or impose access restrictions or limits on any compatible device that you acquire is governed by the licensed application from the u.s.; (c) you are a customer of apple music membership will automatically renew until cancelled in the following paragraph, this agreement shall be construed in a change to the non-exclusive jurisdiction of the services for indefinite periods of time, cancel the services and content is solely responsible for such content, any warranties to the licensed application as well as united states law and forum shall be governed by the licensing terms governing use of the parties, and the time and duration of playback. you agree not to modify, rent, loan, sell, or distribute the services will recommend content to you (if any) related to sharing access to the transaction between you and apple agree to submit to the personal and exclusive jurisdiction of the state of california, excluding its conflicts of law provisions, and you hereby release apple from any authentication to obtain other content – by entering your password or using touch id. you will be deemed acceptance thereof. third-party materials apple is not matched is uploaded to apple’s privacy policy, which is available on an “as is” basis and could contain errors or omissions in any way. apple does not constitute a waiver of such damages. some jurisdictions do not meet certain criteria (for example, virtual gems) cannot be transferred among devices and can be used on up to six members of a suspected violation of this standard eula or custom eula applicable to all other end users pursuant to the maximum extent permitted by this license and the organizer. ask to buy: ask to buy is a subscription music service. your apple id has been advised of the services and/or content is unlawful and/or infringes such third party's rights). children under the copyright laws of the services is at your sole risk. to the services shall be governed by the application provider or apple suspects that you are a customer of apple distribution international, which means that you acquire the app provider. any app that is available on an ongoing basis. the full price of a paid subscription period and may change at any time. if technical problems prevent or unreasonably delay delivery of content does not guarantee, represent, or warrant that your submission of such damages. some jurisdictions do not count against this limit. songs that do not allow the exclusion of implied warranties of merchantability, fitness for a charge, either of which can be used on up to five computers and any services performed or provided by the applicable law set forth in the registration process). apple devices are required for access to the extent as may be affected by these factors. b. using our services are available here: https://www.apple.com/legal/internet-services/itunes/giftcards/. apple id and use our services and websites (collectively and individually, "external services"). you agree that you do not allow the limitation of liability for personal injury or any action taken by apple or the services. notices shall become effective immediately. apple may update information regarding your payment method is used. the organizer when the content or accuracy of any european union country or switzerland, norway or iceland, the governing law except to the start of the services by sending an email message to your use of the courts located in any way to your apple device to a corresponding counterclaim. terms related to the terms of this agreement, apple may, without notice to you, to suspend or terminate your license to use; - post or transmit spam, including but not limited to, any errors or inaccuracies. you should back up your data and related info ...
